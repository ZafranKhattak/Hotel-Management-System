# %% [markdown]
# #                           HOTEL BOOKING APP
# *  1) AUTH
# *  2) DASHBOARD | MENU | BOOK A ROOM (PRICE| LOW | MEDIUM | HIGH| ) ABOUT HOTEL(HISTORY)
# *  3) DATABASE

# %% [markdown]
# # HISTORY
# * BUILT IN
# * OWNER
# * BRANCHES
# * WELCOME NOTE
# * About
# * Branches
